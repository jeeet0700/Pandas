# %%
import pandas as pd

data = {
    'Name': ['Julie Dsouza', 'Kelly Sebastian', 'Daniel Fernandez', 'Julie Dsouza', 'John Jacob'],
    'Product': ['Apple Airpods Headphones', 'Apple Airpods Headphones', '27in 4K Gaming Monitor', 'Bose SoundSport Headphones', 'Wired Headphones'],
    'Quantity Ordered': [1, 1, 1, 1, 2],
    'Price Each': [150.00, 150.00, 389.99, 99.99, 11.99],
    'Order Date': ['01/22/19 21:20', '01/24/19 8:13', '01/26/19 12:16', '01/01/19 10:30', '01/17/19 13:33'],
    'Purchase Address': ['868 Willow St, Los Angeles, CA 90001', '442 Cedar St, Portland, OR 97035', '741 10th St, Los Angeles, CA 90001', '867 Willow St, Los Angeles, CA 90001', '946 Walnut St, Boston, MA 02215']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#                Name                     Product  Quantity Ordered  Price Each  \
# 0      Julie Dsouza    Apple Airpods Headphones                 1      150.00
# 1   Kelly Sebastian    Apple Airpods Headphones                 1      150.00
# 2  Daniel Fernandez      27in 4K Gaming Monitor                 1      389.99
# 3      Julie Dsouza  Bose SoundSport Headphones                 1       99.99
# 4        John Jacob            Wired Headphones                 2       11.99
#
#        Order Date                      Purchase Address
# 0  01/22/19 21:20  868 Willow St, Los Angeles, CA 90001
# 1   01/24/19 8:13      442 Cedar St, Portland, OR 97035
# 2  01/26/19 12:16    741 10th St, Los Angeles, CA 90001
# 3  01/01/19 10:30  867 Willow St, Los Angeles, CA 90001
# 4  01/17/19 13:33       946 Walnut St, Boston, MA 02215

# %%
df1=df.groupby('Name')['Quantity Ordered'].count().reset_index()

# %%
df1
# Out:
#                Name  Quantity Ordered
# 0  Daniel Fernandez                 1
# 1        John Jacob                 1
# 2      Julie Dsouza                 2
# 3   Kelly Sebastian                 1

# %%
df2=df1.loc[df1['Quantity Ordered']==2][['Name']]
df2
# Out:
#            Name
# 2  Julie Dsouza

# %%
df3=df.groupby('Name')['Price Each'].mean().reset_index()
df3.loc[df3['Price Each']>100]
# Out:
#                Name  Price Each
# 0  Daniel Fernandez     389.990
# 2      Julie Dsouza     124.995
# 3   Kelly Sebastian     150.000

# %%
df3.loc[df3['Price Each']>100]
# Out:
#                Name  Price Each
# 0  Daniel Fernandez     389.990
# 2      Julie Dsouza     124.995
# 3   Kelly Sebastian     150.000

# %%
df2
# Out:
#            Name
# 2  Julie Dsouza

# %%
df2.loc[df2['Name'].isin(df3['Name'])]
# Out:
#            Name
# 2  Julie Dsouza

# %%
df
# Out:
#                Name                     Product  Quantity Ordered  Price Each  \
# 0      Julie Dsouza    Apple Airpods Headphones                 1      150.00
# 1   Kelly Sebastian    Apple Airpods Headphones                 1      150.00
# 2  Daniel Fernandez      27in 4K Gaming Monitor                 1      389.99
# 3      Julie Dsouza  Bose SoundSport Headphones                 1       99.99
# 4        John Jacob            Wired Headphones                 2       11.99
#
#        Order Date                      Purchase Address
# 0  01/22/19 21:20  868 Willow St, Los Angeles, CA 90001
# 1   01/24/19 8:13      442 Cedar St, Portland, OR 97035
# 2  01/26/19 12:16    741 10th St, Los Angeles, CA 90001
# 3  01/01/19 10:30  867 Willow St, Los Angeles, CA 90001
# 4  01/17/19 13:33       946 Walnut St, Boston, MA 02215

# %%
df['avg']=df.groupby('Name')['Price Each'].transform('mean')

# %%
df
# Out:
#                Name                     Product  Quantity Ordered  Price Each  \
# 0      Julie Dsouza    Apple Airpods Headphones                 1      150.00
# 1   Kelly Sebastian    Apple Airpods Headphones                 1      150.00
# 2  Daniel Fernandez      27in 4K Gaming Monitor                 1      389.99
# 3      Julie Dsouza  Bose SoundSport Headphones                 1       99.99
# 4        John Jacob            Wired Headphones                 2       11.99
#
#        Order Date                      Purchase Address      avg
# 0  01/22/19 21:20  868 Willow St, Los Angeles, CA 90001  124.995
# 1   01/24/19 8:13      442 Cedar St, Portland, OR 97035  150.000
# 2  01/26/19 12:16    741 10th St, Los Angeles, CA 90001  389.990
# 3  01/01/19 10:30  867 Willow St, Los Angeles, CA 90001  124.995
# 4  01/17/19 13:33       946 Walnut St, Boston, MA 02215   11.990

# %%
df.loc[df['Price Each'] > df['avg']]
# Out:
#            Name                   Product  Quantity Ordered  Price Each  \
# 0  Julie Dsouza  Apple Airpods Headphones                 1       150.0
#
#        Order Date                      Purchase Address      avg  avg1
# 0  01/22/19 21:20  868 Willow St, Los Angeles, CA 90001  124.995   NaN

# %%
df['avg1']=df.groupby('Name')['Price Each'].mean()

# %%
df
# Out:
#                Name                     Product  Quantity Ordered  Price Each  \
# 0      Julie Dsouza    Apple Airpods Headphones                 1      150.00
# 1   Kelly Sebastian    Apple Airpods Headphones                 1      150.00
# 2  Daniel Fernandez      27in 4K Gaming Monitor                 1      389.99
# 3      Julie Dsouza  Bose SoundSport Headphones                 1       99.99
# 4        John Jacob            Wired Headphones                 2       11.99
#
#        Order Date                      Purchase Address      avg  avg1
# 0  01/22/19 21:20  868 Willow St, Los Angeles, CA 90001  124.995   NaN
# 1   01/24/19 8:13      442 Cedar St, Portland, OR 97035  150.000   NaN
# 2  01/26/19 12:16    741 10th St, Los Angeles, CA 90001  389.990   NaN
# 3  01/01/19 10:30  867 Willow St, Los Angeles, CA 90001  124.995   NaN
# 4  01/17/19 13:33       946 Walnut St, Boston, MA 02215   11.990   NaN

# %%
df.groupby('Name')['Price Each'].mean()
# Out:
# Name
# Daniel Fernandez    389.990
# John Jacob           11.990
# Julie Dsouza        124.995
# Kelly Sebastian     150.000
# Name: Price Each, dtype: float64

# %%
ls
# Out:
# 1bNPear-F6sKZ0cIJgvodUq09ZnwALQ02
# DV/
# DV.ipynb
# Data Viz Interview Prep.ipynb
# Descriptive Stat.ipynb
# Gaussian Distribution.ipynb
# NPS.ipynb
# Netflix project II.ipynb
# Netflix project.ipynb
# Numpy Airbnb NPS final .ipynb
# Numpy Pandas/
# Numpy_Interview_Prep.ipynb
# Panda_interview_prep.ipynb
# Pandas Revision.ipynb
# Pandas final cut.ipynb
# Pfizer_1.csv
# Prob and Stat/
# Python Lib Rivision.ipynb
# Python revision.ipynb
# SQL/
# These Are the 25 Smartest Dog Breeds, According to Science.jpeg
# Think Stats, 2nd Edition_ Exploratory Data Analysis ( PDFDrive ).pdf
# Untitled.ipynb
# clouds-2627945.jpg
# directors.csv
# figure.png
# final_vg.csv
# fit.txt
# gapminder.csv
# jupyterthemes.ipynb
# mckinsey.csv
# movies.csv
# sales.csv
# storytelling-with-data-cole-nussbaumer-knaflic.pdf
# survey.txt

# %%
mov=pd.read_csv('movies.csv')
mov.drop(['Unnamed: 0'],axis=1,inplace=True)
mov
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
dire=pd.read_csv('directors.csv')
dire.drop(['Unnamed: 0'],axis=1,inplace=True)
dire
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
mov['director_id'].isin(dire['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
import numpy as np
np.all(mov['director_id'].isin(dire['id']))
# Out:
# True

# %%
df=mov.merge(dire,left_on='director_id',right_on='id')
df.drop(['id_x','id_y'],axis=1,inplace=True)
df
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1460          0          14    25288872                 Enough Said
# 1461    6500000          11    13368437          Friends with Money
# 1462    3000000           5           0                 Please Give
# 1463          0           0           0         Walking and Talking
# 1464     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
df['day'].isin(['Friday'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462     True
# 1463    False
# 1464     True
# Name: day, Length: 1465, dtype: bool

# %%
df.loc[df['day'].isin(['Friday'])]
# Out:
#         budget  popularity    revenue                    title  vote_average  \
# 5     18500000          67  183316455                   Aliens           7.7
# 6      6400000          74   78371200           The Terminator           7.3
# 16    80000000          49  181001478        Road to Perdition           7.3
# 17    72000000          32   96889998                  Jarhead           6.6
# 18    35000000          20   75225693       Revolutionary Road           6.7
# ...        ...         ...        ...                      ...           ...
# 1455  10000000          33  163876815                  Saw III           6.1
# 1457         0           5     188126  Repo! The Genetic Opera           6.7
# 1458   4000000          42  152925093                   Saw II           6.3
# 1462   3000000           5          0              Please Give           6.0
# 1464    250000           1    4186931         Lovely & Amazing           6.3
#
# ...

# %%
df.sort_values(['budget'],ascending=True)
# Out:
#          budget  popularity     revenue  \
# 1134          0           3           0
# 1129          0           3           0
# 404           0          26    68929150
# 605           0          26    73100172
# 931           0           4           0
# ...         ...         ...         ...
# 9     255000000          49    89289910
# 29    258000000         115   890871626
# 47    270000000          57   391081192
# 7     300000000         139   961000000
# 68    380000000         135  1045713802
#
#                                             title  vote_average  vote_count  \
# 1134                                  School Daze           6.2          26
# 1129                                Summer of Sam           6.3         112
# 404                                 Anna Karenina           6.5         639
# 605                           Here Comes the Boom           6.0         593
# 931                                       Mumford           6.3          26
# ...

# %%
df.sort_values(['budget'],ascending=False)
# Out:
#          budget  popularity     revenue  \
# 68    380000000         135  1045713802
# 7     300000000         139   961000000
# 47    270000000          57   391081192
# 29    258000000         115   890871626
# 9     255000000          49    89289910
# ...         ...         ...         ...
# 1115          0           6           0
# 1112          0           5    47231070
# 1361          0           7           0
# 957           0           9           0
# 414           0          20    43312294
#
#                                             title  vote_average  vote_count  \
# 68    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 7        Pirates of the Caribbean: At World's End           6.9        4500
# 47                               Superman Returns           5.4        1400
# 29                                   Spider-Man 3           5.9        3576
# 9                                 The Lone Ranger           5.9        2311
# ...

# %%
df.sort_values(['budget','revenue'],ascending=[True,False])
# Out:
#          budget  popularity     revenue  \
# 593           0          22   181466833
# 997           0          16   141702264
# 1082          0           6   106269971
# 687           0          16   104907746
# 677           0          21    92863945
# ...         ...         ...         ...
# 9     255000000          49    89289910
# 29    258000000         115   890871626
# 47    270000000          57   391081192
# 7     300000000         139   961000000
# 68    380000000         135  1045713802
#
#                                             title  vote_average  vote_count  \
# 593              Scooby-Doo 2: Monsters Unleashed           5.4         500
# 997               Garfield: A Tail of Two Kitties           5.1         464
# 1082                           Mr. Holland's Opus           6.9         113
# 687                                  The Campaign           5.6         578
# 677                       House of Flying Daggers           7.1         439
# ...

# %%
df.sort_values(['budget','revenue'],ascending=[False,True])
# Out:
#          budget  popularity     revenue  \
# 68    380000000         135  1045713802
# 7     300000000         139   961000000
# 47    270000000          57   391081192
# 29    258000000         115   890871626
# 9     255000000          49    89289910
# ...         ...         ...         ...
# 677           0          21    92863945
# 687           0          16   104907746
# 1082          0           6   106269971
# 997           0          16   141702264
# 593           0          22   181466833
#
#                                             title  vote_average  vote_count  \
# 68    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 7        Pirates of the Caribbean: At World's End           6.9        4500
# 47                               Superman Returns           5.4        1400
# 29                                   Spider-Man 3           5.9        3576
# 9                                 The Lone Ranger           5.9        2311
# ...

# %%
def cal_profit(x):
    return x['revenue']-x['budget']

# %%
df[['revenue','budget']].apply(cal_profit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/t2/3z1ygvv95h72q7ygpfjbdsgr0000gn/T/ipykernel_5867/1718346628.py in <module>
# ...

# %%
df[['revenue','budget']].apply(cal_profit,axis=1)
# Out:
# 0       2550965087
# 1       1645034188
# 2        420000000
# 3        263882411
# 4         20000098
#            ...
# 1460      25288872
# 1461       6868437
# 1462      -3000000
# 1463             0
# 1464       3936931
# Length: 1465, dtype: int64

# %%
df['profit']=df[['revenue','budget']].apply(cal_profit,axis=1)
df
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1460          0          14    25288872                 Enough Said
# 1461    6500000          11    13368437          Friends with Money
# 1462    3000000           5           0                 Please Give
# 1463          0           0           0         Walking and Talking
# 1464     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
df[['budget']].apply(np.max)
# Out:
# budget    380000000
# dtype: int64

# %%
df[['budget']].apply(np.min)
# Out:
# budget    0
# dtype: int64

# %%
df[['revenue']].apply(np.max)
# Out:
# revenue    2787965087
# dtype: int64

# %%
df[['revenue']].apply(np.min)
# Out:
# revenue    0
# dtype: int64

# %%
df[['revenue']].apply(np.sum)
# Out:
# revenue    209866997305
# dtype: int64

# %%
df[['revenue']].apply(np.sum,axis=1)
# Out:
# 0       2787965087
# 1       1845034188
# 2        520000000
# 3        378882411
# 4         90000098
#            ...
# 1460      25288872
# 1461      13368437
# 1462             0
# 1463             0
# 1464       4186931
# Length: 1465, dtype: int64

# %%
df[['revenue','budget']].apply(np.min)
# Out:
# revenue    0
# budget     0
# dtype: int64

# %%
df[['revenue','budget']].apply(np.sum)
# Out:
# revenue    209866997305
# budget      70353617179
# dtype: int64

# %%
df[['revenue','budget']].apply(np.sum,axis=1)
# Out:
# 0       3024965087
# 1       2045034188
# 2        620000000
# 3        493882411
# 4        160000098
#            ...
# 1460      25288872
# 1461      19868437
# 1462       3000000
# 1463             0
# 1464       4436931
# Length: 1465, dtype: int64

# %%
df['revenue'].max()
# Out:
# 2787965087

# %%
np.max(df['revenue'])
# Out:
# 2787965087

# %%
df.groupby(['director_name'])['year'].agg(['min','max'])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
df.groupby(['director_name'])['year'].agg(['min','max']).reset_index()
# Out:
#                    director_name   min   max
# 0                     Adam McKay  2004  2015
# 1                  Adam Shankman  2001  2012
# 2    Alejandro González Iñárritu  2000  2015
# 3                    Alex Proyas  1994  2016
# 4                Alexander Payne  1999  2013
# ..                           ...   ...   ...
# 194                   Wes Craven  1984  2011
# 195            Wolfgang Petersen  1981  2006
# 196                  Woody Allen  1977  2013
# 197                  Zack Snyder  2004  2016
# 198                  Zhang Yimou  2002  2014
#
# [199 rows x 3 columns]

# %%
df.groupby(['director_name'])[['year','title']].agg({'year':['min','max'],'title':['count']})
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
df.groupby(['director_name'])[['year','title']].agg({'year':['min','max'],'title':['count']}).reset_index()
# Out:
#                    director_name  year       title
#                                    min   max count
# 0                     Adam McKay  2004  2015     6
# 1                  Adam Shankman  2001  2012     8
# 2    Alejandro González Iñárritu  2000  2015     6
# 3                    Alex Proyas  1994  2016     5
# 4                Alexander Payne  1999  2013     5
# ..                           ...   ...   ...   ...
# 194                   Wes Craven  1984  2011    10
# 195            Wolfgang Petersen  1981  2006     7
# 196                  Woody Allen  1977  2013    18
# 197                  Zack Snyder  2004  2016     7
# 198                  Zhang Yimou  2002  2014     6
#
# [199 rows x 4 columns]

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
lambda a : a *10
# Out:
# <function __main__.<lambda>(a)>

# %%
x=lambda a : a * 10

# %%
print(x(3))
# Out:
# 30

# %%
df.groupby(['director_name']).filter(lambda x:x['budget'].max()>10000000)
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1450   10000000           2           0            Adam Resurrected
# 1451    7000000           7     2062066                  Auto Focus
# 1452    5000000           6           0               Light Sleeper
# 1453   15000000          10           0          Dying of the Light
# 1454     250000           6       56825                 The Canyons
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
df['budget'].max()>10000000
# Out:
# True

# %%
def calculate(x):
    x['risky']=(x['budget']-x['revenue'].mean())>0
    return x

# %%
df.groupby(['director_name']).apply(calculate)
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1460          0          14    25288872                 Enough Said
# 1461    6500000          11    13368437          Friends with Money
# 1462    3000000           5           0                 Please Give
# 1463          0           0           0         Walking and Talking
# 1464     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
df
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1460          0          14    25288872                 Enough Said
# 1461    6500000          11    13368437          Friends with Money
# 1462    3000000           5           0                 Please Give
# 1463          0           0           0         Walking and Talking
# 1464     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
def cal_profit(x):
    x['profit123']= x['revenue']-x['budget']
    return x

# %%
df[['budget','revenue']].apply(cal_profit,axis=1)
# Out:
#          budget     revenue   profit123
# 0     237000000  2787965087  2550965087
# 1     200000000  1845034188  1645034188
# 2     100000000   520000000   420000000
# 3     115000000   378882411   263882411
# 4      70000000    90000098    20000098
# ...         ...         ...         ...
# 1460          0    25288872    25288872
# 1461    6500000    13368437     6868437
# 1462    3000000           0    -3000000
# 1463          0           0           0
# 1464     250000     4186931     3936931
#
# [1465 rows x 3 columns]

# %%
df
# Out:
#          budget  popularity     revenue                       title  \
# 0     237000000         150  2787965087                      Avatar
# 1     200000000         100  1845034188                     Titanic
# 2     100000000         101   520000000  Terminator 2: Judgment Day
# 3     115000000          38   378882411                   True Lies
# 4      70000000          24    90000098                   The Abyss
# ...         ...         ...         ...                         ...
# 1460          0          14    25288872                 Enough Said
# 1461    6500000          11    13368437          Friends with Money
# 1462    3000000           5           0                 Please Give
# 1463          0           0           0         Walking and Talking
# 1464     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# ...

# %%
ls
# Out:
# 1bNPear-F6sKZ0cIJgvodUq09ZnwALQ02
# DV/
# DV.ipynb
# Data Viz Interview Prep.ipynb
# Descriptive Stat.ipynb
# Gaussian Distribution.ipynb
# NPS.ipynb
# Netflix project II.ipynb
# Netflix project.ipynb
# Numpy Airbnb NPS final .ipynb
# Numpy Pandas/
# Numpy_Interview_Prep.ipynb
# Panda_interview_prep.ipynb
# Pandas Revision.ipynb
# Pandas final cut.ipynb
# Pfizer_1.csv
# Prob and Stat/
# Python Lib Rivision.ipynb
# Python revision.ipynb
# SQL/
# These Are the 25 Smartest Dog Breeds, According to Science.jpeg
# Think Stats, 2nd Edition_ Exploratory Data Analysis ( PDFDrive ).pdf
# Untitled.ipynb
# clouds-2627945.jpg
# directors.csv
# figure.png
# final_vg.csv
# fit.txt
# gapminder.csv
# jupyterthemes.ipynb
# mckinsey.csv
# movies.csv
# sales.csv
# storytelling-with-data-cole-nussbaumer-knaflic.pdf
# survey.txt

# %%
df=pd.read_csv('Pfizer_1.csv')
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
df_melt=pd.melt(df,
       id_vars=['Date','Drug_Name','Parameter'],
       var_name='Time',
       value_name='Reading')
df_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
pd.melt?

# %%
df_melt.pivot(index=['Date','Drug_Name','Time'],
             columns='Parameter',
             values='Reading')
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               Time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [108 rows x 2 columns]

# %%
df_melt_pivot=df_melt.pivot(index=['Date','Drug_Name','Time'],
             columns='Parameter',
             values='Reading').reset_index()
df_melt_pivot
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
pd.pivot_table(data=df_melt_pivot,
              index='Drug_Name',
              columns='Date',
              values='Temperature')
# Out:
# Date                     15-10-2020  16-10-2020  17-10-2020
# Drug_Name
# diltiazem hydrochloride   21.454545   37.454545   15.636364
# docetaxel injection       20.750000   51.454545   17.500000
# ketamine hydrochloride    23.555556   11.500000   18.500000

# %%
pd.pivot_table?

# %%
pd.pivot_table(data=df_melt_pivot,
               index='Drug_Name',
               columns='Date',
               values=['Temperature'],
               aggfunc='min',
               margins=True)
# Out:
# Parameter               Temperature
# Date                     15-10-2020 16-10-2020 17-10-2020   All
# Drug_Name
# diltiazem hydrochloride        20.0       34.0       10.0  10.0
# docetaxel injection            17.0       46.0       12.0  12.0
# ketamine hydrochloride         20.0        8.0       13.0   8.0
# All                            17.0        8.0       10.0   8.0

# %%
df.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
df.isna()
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pd.melt?

# %%
pd.melt(
    df,
    id_vars=['Date','Drug_Name','Parameter'],
    var_name='Time',
    value_name='Reading'
)
# Out:
#            Date                Drug_Name    Parameter      Time  Reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
pd.pivot?

# %%
df_melt=pd.melt(df,
               id_vars=['Date','Drug_Name','Parameter'],
               var_name='Time',
               value_name='Reading')
df_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
pd.pivot(df_melt,
        index=['Date','Drug_Name','Time'],
        columns='Parameter',
        values='Reading')
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               Time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [108 rows x 2 columns]

# %%
df_mp=pd.pivot(df_melt,
        index=['Date','Drug_Name','Time'],
        columns='Parameter',
        values='Reading').reset_index()
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
df_mp.groupby(['Date','Drug_Name'])['Temperature'].mean()
# Out:
# Date        Drug_Name
# 15-10-2020  diltiazem hydrochloride    21.454545
#             docetaxel injection        20.750000
#             ketamine hydrochloride     23.555556
# 16-10-2020  diltiazem hydrochloride    37.454545
#             docetaxel injection        51.454545
#             ketamine hydrochloride     11.500000
# 17-10-2020  diltiazem hydrochloride    15.636364
#             docetaxel injection        17.500000
#             ketamine hydrochloride     18.500000
# Name: Temperature, dtype: float64

# %%
df_mp.groupby(['Date','Drug_Name'])['Temperature'].mean().reset_index()
# Out:
#          Date                Drug_Name  Temperature
# 0  15-10-2020  diltiazem hydrochloride    21.454545
# 1  15-10-2020      docetaxel injection    20.750000
# 2  15-10-2020   ketamine hydrochloride    23.555556
# 3  16-10-2020  diltiazem hydrochloride    37.454545
# 4  16-10-2020      docetaxel injection    51.454545
# 5  16-10-2020   ketamine hydrochloride    11.500000
# 6  17-10-2020  diltiazem hydrochloride    15.636364
# 7  17-10-2020      docetaxel injection    17.500000
# 8  17-10-2020   ketamine hydrochloride    18.500000

# %%
pd.cut?

# %%
pd.cut(df_mp['Temperature'],
      bins=[5,20,35,50,65],
      labels=['low','med','high','vhigh'])
# Out:
# 0      low
# 1      low
# 2      med
# 3      med
# 4      med
#       ...
# 103    low
# 104    low
# 105    low
# 106    low
# 107    med
# Name: Temperature, Length: 108, dtype: category
# Categories (4, object): ['low' < 'med' < 'high' < 'vhigh']

# %%
df_mp['temp_cat']=pd.cut(df_mp['Temperature'],
      bins=[5,20,35,50,65],
      labels=['low','med','high','vhigh'])
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat
# 0                 20.0      low
# 1                 20.0      low
# 2                 21.0      med
# ...

# %%
df_mp['Temperature'].min()
# Out:
# 8.0

# %%
df_mp.loc[df_mp['Temperature']==8.0]
# Out:
# Parameter        Date               Drug_Name     Time  Pressure  Temperature  \
# 63         16-10-2020  ketamine hydrochloride  1:30:00      12.0          8.0
#
# Parameter temp_cat
# 63             low

# %%
df_mp['Temperature'].max()
# Out:
# 58.0

# %%
df_mp.head()
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
#
# Parameter  Temperature temp_cat
# 0                 20.0      low
# 1                 20.0      low
# 2                 21.0      med
# 3                 23.0      med
# 4                 22.0      med

# %%
df_mp['Drug_Name'].str.contains('diltiazem')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# Name: Drug_Name, Length: 108, dtype: bool

# %%
df_mp.loc[df_mp['Drug_Name'].str.contains('diltiazem')]
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# 5          15-10-2020  diltiazem hydrochloride   3:30:00       NaN
# 6          15-10-2020  diltiazem hydrochloride   4:30:00      11.0
# 7          15-10-2020  diltiazem hydrochloride   5:30:00      13.0
# 8          15-10-2020  diltiazem hydrochloride   6:30:00      14.0
# 9          15-10-2020  diltiazem hydrochloride   7:30:00      16.0
# 10         15-10-2020  diltiazem hydrochloride   8:30:00      16.0
# 11         15-10-2020  diltiazem hydrochloride   9:30:00      24.0
# 36         16-10-2020  diltiazem hydrochloride  10:30:00      24.0
# ...

# %%
df_mp.loc[df_mp['Drug_Name'].str.contains('hydrochloride')]
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat
# 0                 20.0      low
# 1                 20.0      low
# 2                 21.0      med
# ...

# %%
df_mp.loc[df_mp['Drug_Name'].str.contains('hydrochloride')]['Drug_Name']
# Out:
# 0      diltiazem hydrochloride
# 1      diltiazem hydrochloride
# 2      diltiazem hydrochloride
# 3      diltiazem hydrochloride
# 4      diltiazem hydrochloride
#                 ...
# 103     ketamine hydrochloride
# 104     ketamine hydrochloride
# 105     ketamine hydrochloride
# 106     ketamine hydrochloride
# 107     ketamine hydrochloride
# Name: Drug_Name, Length: 72, dtype: object

# %%
df_mp.loc[df_mp['Drug_Name'].str.contains('hydrochloride')]['Drug_Name'].unique()
# Out:
# array(['diltiazem hydrochloride', 'ketamine hydrochloride'], dtype=object)

# %%
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat
# 0                 20.0      low
# 1                 20.0      low
# 2                 21.0      med
# ...

# %%
df_mp['Drug_Name'].str.contains('ketamine')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 103     True
# 104     True
# 105     True
# 106     True
# 107     True
# Name: Drug_Name, Length: 108, dtype: bool

# %%
df_mp.loc[df_mp['Drug_Name'].str.contains('ketamine')]
# Out:
# Parameter        Date               Drug_Name      Time  Pressure  \
# 24         15-10-2020  ketamine hydrochloride  10:30:00       9.0
# 25         15-10-2020  ketamine hydrochloride  11:30:00       9.0
# 26         15-10-2020  ketamine hydrochloride  12:30:00      11.0
# 27         15-10-2020  ketamine hydrochloride   1:30:00       8.0
# 28         15-10-2020  ketamine hydrochloride   2:30:00       NaN
# 29         15-10-2020  ketamine hydrochloride   3:30:00       NaN
# 30         15-10-2020  ketamine hydrochloride   4:30:00       7.0
# 31         15-10-2020  ketamine hydrochloride   5:30:00       NaN
# 32         15-10-2020  ketamine hydrochloride   6:30:00       9.0
# 33         15-10-2020  ketamine hydrochloride   7:30:00      10.0
# 34         15-10-2020  ketamine hydrochloride   8:30:00      11.0
# 35         15-10-2020  ketamine hydrochloride   9:30:00      10.0
# 60         16-10-2020  ketamine hydrochloride  10:30:00      16.0
# ...

# %%
df_mp['Drug_Name'].str.len()>10
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 103    True
# 104    True
# 105    True
# 106    True
# 107    True
# Name: Drug_Name, Length: 108, dtype: bool

# %%
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat
# 0                 20.0      low
# 1                 20.0      low
# 2                 21.0      med
# ...

# %%
df_mp['TimeStamp']=df_mp['Date']+' '+df_mp['Time']
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat            TimeStamp
# 0                 20.0      low  15-10-2020 10:30:00
# 1                 20.0      low  15-10-2020 11:30:00
# ...

# %%
df_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         108 non-null    object
#  1   Drug_Name    108 non-null    object
#  2   Time         108 non-null    object
#  3   Pressure     95 non-null     float64
#  4   Temperature  95 non-null     float64
#  5   temp_cat     95 non-null     category
#  6   TimeStamp    108 non-null    object
# dtypes: category(1), float64(2), object(4)
# memory usage: 5.5+ KB

# %%
df_mp['TimeStamp']=pd.to_datetime(df_mp['TimeStamp'])

# %%
df_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         108 non-null    object
#  1   Drug_Name    108 non-null    object
#  2   Time         108 non-null    object
#  3   Pressure     95 non-null     float64
#  4   Temperature  95 non-null     float64
#  5   temp_cat     95 non-null     category
#  6   TimeStamp    108 non-null    datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), object(3)
# memory usage: 5.5+ KB

# %%
ts=df_mp['TimeStamp'][0]

# %%
ts
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
ts.year
# Out:
# 2020

# %%
ts.month
# Out:
# 10

# %%
ts.month_name()
# Out:
# 'October'

# %%
ts.day
# Out:
# 15

# %%
ts.day_name()
# Out:
# 'Thursday'

# %%
ts.hour
# Out:
# 10

# %%
ts.minute
# Out:
# 30

# %%
ts.day_of_week
# Out:
# 3

# %%
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
df_mp
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature temp_cat           TimeStamp
# 0                 20.0      low 2020-10-15 10:30:00
# 1                 20.0      low 2020-10-15 11:30:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB
